# %% [markdown]
# ## Sets
#
# A set is a built-in data type in Python used to store multiple unique items in a single variable.
#
# - Sets are unordered → no indexing or slicing.
# - Sets are mutable → you can add/remove elements.
# - Sets are unique → duplicates are automatically removed.
# - Sets are defined using curly braces {} or the set() constructor.

# %% [markdown]
# ### Creating a Set

# %%
fruits = {"apples", "bananas", "cherries", "dates", "apples"}

#set of integers
numbers = set([1, 2, 3, 4, 5, 1, 2])

numbers
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ```Note:```
# - An empty set must be created with set() not {}
# - {} creates an empty dictionary.

# %% [markdown]
# ### Common Set Methods
#
# | Method               | Description                                         | Example                             |
# |----------------------|-----------------------------------------------------|-------------------------------------|
# | `add(x)`             | Adds an element `x` to the set                      | `fruits.add('orange')`              |
# | `remove(x)`          | Removes `x` from the set (error if not found)       | `fruits.remove('banana')`           |
# | `discard(x)`         | Removes `x` if present, does nothing if not         | `fruits.discard('apple')`           |
# | `pop()`              | Removes and returns a random element                | `fruits.pop()`                      |
# | `clear()`            | Removes all elements from the set                   | `fruits.clear()`                    |
# | `update(iterable)`   | Adds multiple elements from an iterable             | `fruits.update(['pear', 'kiwi'])`   |
# | `copy()`             | Returns a shallow copy of the set                   | `new_set = fruits.copy()`           |

# %%
fruits
# Out:
# {'apples', 'bananas', 'cherries', 'dates'}

# %%
#Add an element
fruits.add("mangoes")
fruits
# Out:
# {'apples', 'bananas', 'cherries', 'dates', 'mangoes'}

# %%
#Add multiple elements
fruits.update(["kiwis", "pears"])
fruits
# Out:
# {'apples', 'bananas', 'cherries', 'dates', 'kiwis', 'mangoes', 'pears'}

# %%
fruits.remove("kiwis")
fruits
# Out:
# {'apples', 'bananas', 'cherries', 'dates', 'mangoes', 'pears'}

# %%
fruits.remove("pineapples")  # This will raise a KeyError because "pineapples" is not in the set
fruits
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fruits.remove("pineapples")  # This will raise a KeyError because "pineapples" is not in the set
#       2 fruits
#
# KeyError: 'pineapples'

# %%
fruits.discard("pineapples") # This will not raise an error

# %%
fruits
# Out:
# {'apples', 'bananas', 'cherries', 'dates', 'mangoes', 'pears'}

# %%
removed_fruit = fruits.pop()
removed_fruit
# Out:
# 'bananas'

# %%
fruits.clear()
fruits
# Out:
# set()
