# %% [markdown]
# # Week 2 Pandas Project: Global Superstore Analysis
#
# ## Dataset
#
# **Global Superstore Dataset:** [Kaggle](https://www.kaggle.com/datasets/rohitgrewal/global-superstore-data)
#
# **Orders**: Contains detailed records of customer orders, products, sales, discounts and profits.
#
# **Returns**: Lists orders that have been returned.
#
# **People**: Maps sales personnel to specific sales regions.
#
# ## Background
#
# You are a data analyst working with a global retail company. Your task is to use **Pandas** to clean, transform, combine and analyze sales data to uncover useful business insights.
#
# ## Project Tasks
#
# ### 1. Load and Explore the Data
#
# **Concepts: Pandas Objects, Data Indexing and Selection**
#
# * Load the Orders, Returns, and People datasets into Pandas.
# * Inspect the shape, columns, data types, and basic statistics of each DataFrame.
# * Explore Pandas Series and DataFrames.
# * Select specific rows and columns from the datasets.
# * Filter the data using relevant conditions.
#
# ### 2. Clean and Prepare the Data
#
# **Concepts: Data Manipulation, Handling Missing Data**
#
# * Identify missing values in the datasets.
# * Handle missing values appropriately.
# * Check for duplicate records.
# * Check and correct data types where necessary.
# * Create or modify columns that will be useful for the analysis.
#
# ### 3. Perform Operations on the Data
#
# **Concept: Operations on Data**
#
# Use Pandas operations to create and analyze the following:
#
# * Calculate the **total sales value**.
# * Calculate the **total profit**.
# * Calculate the **total quantity of products sold**.
# * Calculate the **average discount**.
# * Calculate the **total shipping cost**.
# * Create a **Shipping Duration** column showing the number of days between Order Date and Ship Date.
# * Create a **Profit Margin** column to show profit as a percentage of sales.
# * Identify the products or orders with the highest and lowest profit margins.
#
#
# ### 4. Combine the Datasets
#
# **Concepts: `merge` or `concat`**
#
# Use **either `merge()` or `concat()`** to combine datasets or compatible subsets of data.
#
# * Choose an appropriate dataset combination for your operation.
# * Combine the data correctly.
# * Explain why you chose `merge()` or `concat()` and how it applies to your data.
#
# ### 5. Group and Aggregate the Data
#
# **Concept: Aggregation and Grouping**
#
# Use grouping and aggregation to analyze performance by fields such as:
#
# * Market
# * Region
# * Country
# * Category
# * Sub-Category
# * Segment
#
# Calculate appropriate statistics such as total sales, total profit, average sales, quantity sold, or number of orders.
#
# ### 6. Create a Pivot Table
#
# **Concept: Pivot Tables**
#
# Create at least **one pivot table** to compare business performance across two or more dimensions.
#
# Use fields such as Market, Region, Category, Segment, or Order Priority.
#
# ### 7. Work with Strings
#
# **Concept: String Operations**
#
# Use Pandas string methods to answer the following:
#
# 1. How many products contain the word **"Chair"** in their product name?
# 2. How many customers have the word **"Smith"** in their name?
# 3. Create a new column containing the **first word of each Product Name**.
# 4. Which **5 first words** appear most frequently in Product Names?
#
# ### 8. Analyze Sales Over Time
#
# **Concept: Working with Time Series**
#
# * Convert Order Date and Ship Date to datetime format.
# * Analyze sales and profit over time.
# * Compare performance across different months and years.
# * Calculate shipping duration using the order and ship dates.
# * Identify important trends.
#
# ### 9. Use Hierarchical Indexing
#
# **Concept: Hierarchical Indexing**
#
# Create a **MultiIndex** using two related variables, such as:
#
# * Region and Category
# * Market and Category
# * Category and Sub-Category
# * Year and Month
#
# Use the MultiIndex to select and analyze specific groups.
#
# ### 10. Present Your Findings
#
# Summarize the key insights from your analysis.
#
# Your findings should address questions such as:
#
# * Which markets or regions perform best?
# * Which categories and sub-categories are most profitable?
# * Which customer segment generates the most sales?
# * How does discounting relate to profit?
# * How does sales performance change over time?
# * What other interesting patterns did you discover?
#
# Conclude with a **short business summary** of your findings.
#
# ## Submission
#
# Submit **one Jupyter Notebook (`.ipynb`)** containing:
#
# * Your Pandas analysis
# * Outputs
# * Short explanations of your findings
# * Final business summary
