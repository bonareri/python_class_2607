# %% [markdown]
# ### Combining datasets in Pandas
#
# Some of the most interesting studies of data come from combining different data sources.
# These operations can involve anything from very straightforward concatenation of two different datasets to more complicated database-style joins and merges that correctly handle any overlaps between the datasets.
# `Series` and ``DataFrame``s are built with this type of operation in mind, and Pandas includes functions and methods that make this sort of data wrangling fast and straightforward.
#
# Here we'll take a look at simple concatenation of `Series` and ``DataFrame``s with the `pd.concat` function; later we'll dive into more sophisticated in-memory merges and joins implemented in Pandas.
#
# We begin with the standard imports:
#
# #### Common Ways to Combine Datasets
# 1. Concatenation `(pd.concat)`
# Used to stack DataFrames either vertically (rows) or horizontally (columns).
#
# `Stack Rows (same columns)`

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({'ID': [1, 2], 'Name': ['Alice', 'Bob']})
df2 = pd.DataFrame({'ID': [3, 4], 'Name': ['Carol', 'David']})

result = pd.concat([df1, df2])

# %%
result
# Out:
#    ID   Name
# 0   1  Alice
# 1   2    Bob
# 0   3  Carol
# 1   4  David

# %% [markdown]
# `Stack Columns (same rows)`

# %%
df1 = pd.DataFrame({'ID': [1, 2], 'Name': ['Alice', 'Bob']})
df2 = pd.DataFrame({'ID': [3, 4], 'Name': ['Carol', 'David']})

result = pd.concat([df1, df2], axis=1)
result
# Out:
#    ID   Name  ID   Name
# 0   1  Alice   3  Carol
# 1   2    Bob   4  David

# %%
pd.concat([df1, df2], join='outer')
# Out:
#    ID   Name
# 0   1  Alice
# 1   2    Bob
# 0   3  Carol
# 1   4  David

# %% [markdown]
# 2. Merging `(pd.merge)`
#
# Similar to SQL joins. You merge on key columns.
#
# syntax
# ```python
# pd.merge(left, right, on=None, how='inner')
# ```
#
# | Part    | Meaning                                                    |
# | ------- | ---------------------------------------------------------- |
# | `left`  | The first DataFrame (e.g., `df1`)                          |
# | `right` | The second DataFrame (e.g., `df2`)                         |
# | `on`    | Column name(s) to join on (must exist in both DataFrames)  |
# | `how`   | Type of join: `'inner'`, `'left'`, `'right'`, or `'outer'` |

# %% [markdown]
# #### Join Types
#
# | `how=` value | Description                                                                       |
# | ------------ | --------------------------------------------------------------------------------- |
# | `'inner'`    | Returns rows with matching keys in both DataFrames (default)                      |
# | `'left'`     | All rows from the left DataFrame + matching rows from the right (NaN if no match) |
# | `'right'`    | All rows from the right DataFrame + matching rows from the left (NaN if no match) |
# | `'outer'`    | All rows from both DataFrames, fill missing with NaN                              |

# %% [markdown]
# Example Scenario: Customers and Orders
#
# Dataset 1: Customers (df_customers)

# %%
df_customers = pd.DataFrame({
    'CustomerID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Country': ['Kenya', 'Uganda', 'Kenya']
})
df_customers
# Out:
#    CustomerID     Name Country
# 0           1    Alice   Kenya
# 1           2      Bob  Uganda
# 2           3  Charlie   Kenya

# %% [markdown]
#  Dataset 2: Orders (df_orders)

# %%
df_orders = pd.DataFrame({
    'OrderID': [101, 102, 103, 104],
    'CustomerID': [2, 1, 2, 4],
    'Amount': [250, 150, 300, 500]
})
df_orders
# Out:
#    OrderID  CustomerID  Amount
# 0      101           2     250
# 1      102           1     150
# 2      103           2     300
# 3      104           4     500

# %% [markdown]
#  1. Inner Join – Only customers who have orders

# %%
pd.merge(df_customers, df_orders, on='CustomerID', how='inner')
# Out:
#    CustomerID   Name Country  OrderID  Amount
# 0           2    Bob  Uganda      103     300
# 1           2    Bob  Uganda      101     250
# 2           1  Alice   Kenya      102     150

# %% [markdown]
# 2. Left Join – All customers, even if they didn’t order

# %%
pd.merge(df_customers, df_orders, on='CustomerID', how='left')
# Out:
#    CustomerID     Name Country  OrderID  Amount
# 0           1    Alice   Kenya    102.0   150.0
# 1           2      Bob  Uganda    101.0   250.0
# 2           2      Bob  Uganda    103.0   300.0
# 3           3  Charlie   Kenya      NaN     NaN

# %% [markdown]
# 3. Right Join – All orders, even if customer not found

# %%
pd.merge(df_customers, df_orders, on='CustomerID', how='right')
# Out:
#    CustomerID   Name Country  OrderID  Amount
# 0           2    Bob  Uganda      101     250
# 1           1  Alice   Kenya      102     150
# 2           2    Bob  Uganda      103     300
# 3           4    NaN     NaN      104     500

# %% [markdown]
# 4. Outer Join – All customers and all orders

# %%
pd.merge(df_customers, df_orders, on='CustomerID', how='outer')
# Out:
#    CustomerID     Name Country  OrderID  Amount
# 0           1    Alice   Kenya    102.0   150.0
# 1           2      Bob  Uganda    101.0   250.0
# 2           2      Bob  Uganda    103.0   300.0
# 3           3  Charlie   Kenya      NaN     NaN
# 4           4      NaN     NaN    104.0   500.0

# %% [markdown]
# ### Joins
#
# In Pandas, `.join()` is another way to combine datasets, similar to merge(), but with a slightly different use case and syntax.
#
# It is best used when joining on the index or when you want a simpler syntax for merging by key.
#
# Syntax
# ```python
# df1.join(df2, how='left', on=None)
# ```
#
# - `df1` is the left DataFrame.
# - `df2` is the right DataFrame.
# - `on` specifies the column to join on (if not index).
# - `how` can be 'left', 'right', 'inner', 'outer'.

# %% [markdown]
# Join on Index

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
}, index=[1, 2, 3])
df1
# Out:
#       Name  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   35

# %%
df2 = pd.DataFrame({
    'Salary': [50000, 60000, 70000]
}, index=[1, 2, 3])
df2
# Out:
#    Salary
# 1   50000
# 2   60000
# 3   70000

# %%
result = df1.join(df2)
result
# Out:
#       Name  Age  Salary
# 1    Alice   25   50000
# 2      Bob   30   60000
# 3  Charlie   35   70000

# %% [markdown]
# Join on Column Instead of Index

# %%
df1 = pd.DataFrame({
    'CustomerID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})
df1
# Out:
#    CustomerID     Name
# 0           1    Alice
# 1           2      Bob
# 2           3  Charlie

# %%
df2 = pd.DataFrame({
    'CustomerID': [1, 2],
    'Salary': [50000, 60000]
})
df2
# Out:
#    CustomerID  Salary
# 0           1   50000
# 1           2   60000

# %%
df1 = df1.set_index('CustomerID')
df1
# Out:
#                Name
# CustomerID
# 1             Alice
# 2               Bob
# 3           Charlie

# %%
df2 = df2.set_index('CustomerID')
df2
# Out:
#             Salary
# CustomerID
# 1            50000
# 2            60000

# %%
result = df1.join(df2, how='left')
result
# Out:
#                Name   Salary
# CustomerID
# 1             Alice  50000.0
# 2               Bob  60000.0
# 3           Charlie      NaN

# %% [markdown]
# #### When to Use `.join()`:
# - When joining on the index.
# - When you want a simpler syntax than merge() for small tasks.
# - When doing one-to-one or one-to-many joins.

# %% [markdown]
# ### Pandas String Operations
#
# In previous sections, we saw how tools like NumPy and Pandas generalize arithmetic operations so that we can easily and quickly perform the same operation on many array elements. For example:

# %%
import numpy as np
x = np.array([2, 3, 5, 7, 11, 13])
x * 2
# Out:
# array([ 4,  6, 10, 14, 22, 26])

# %% [markdown]
# - This `vectorization` of operations simplifies the syntax of operating on arrays of data:
# - For arrays of strings, NumPy does not provide such simple access, and thus you’re stuck using a loop syntax:

# %%
data = ['peter', 'Paul', 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ['Peter', 'Paul', 'Mary', 'Guido']

# %% [markdown]
# `.capitalize()` method:
#
# - Converts the first character of the string to uppercase
# - Converts the rest of the characters to lowercase

# %% [markdown]
# This is perhaps sufficient to work with some data, but it will break if there are any missing values. For example:

# %%
data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
# ----> 2 [s.capitalize() for s in data]
#
# AttributeError: 'NoneType' object has no attribute 'capitalize'

# %% [markdown]
# Pandas includes features to address both this need for `vectorized string` operations and for correctly handling missing data via the `str` attribute of Pandas Series and Index objects containing strings.
#
# So, for example, suppose we create a Pandas Series with this data:

# %%
import pandas as pd
names = pd.Series(data)
names
# Out:
# 0    peter
# 1     Paul
# 2     MARY
# 3    gUIDO
# dtype: str

# %% [markdown]
# We can now call a single method that will capitalize all the entries, while skipping over any missing values:

# %%
names.str.capitalize()
# Out:
# 0    Peter
# 1     Paul
# 2     Mary
# 3    Guido
# dtype: str

# %% [markdown]
# #### Tables of Pandas String Methods

# %%
monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam',
                   'Eric Idle', 'Terry Jones', 'Michael Palin'])
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: str

# %%
monte.str.lower()
# Out:
# 0    graham chapman
# 1       john cleese
# 2     terry gilliam
# 3         eric idle
# 4       terry jones
# 5     michael palin
# dtype: str

# %% [markdown]
# Notice that these have various return values. Some, like lower(), return a series of strings:

# %% [markdown]
# But some others return numbers:

# %%
monte.str.len()
# Out:
# 0    14
# 1    11
# 2    13
# 3     9
# 4    11
# 5    13
# dtype: int64

# %% [markdown]
# Or Boolean values:

# %%
monte.str.startswith('T')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# Still others return lists or other compound values for each element:

# %%
monte.str.split()
# Out:
# 0    [Graham, Chapman]
# 1       [John, Cleese]
# 2     [Terry, Gilliam]
# 3         [Eric, Idle]
# 4       [Terry, Jones]
# 5     [Michael, Palin]
# dtype: object

# %% [markdown]
# #### Methods similar to Python string methods
#
# Nearly all Python’s built-in string methods are mirrored by a Pandas vectorized string method.
#
# Here is a list of Pandas `str` methods that mirror Python string methods:
#
# | Python String Method  | Pandas `.str` Method          | Description                                       |
# | --------------------- | ----------------------------- | ------------------------------------------------- |
# | `s.lower()`           | `series.str.lower()`          | Converts string to lowercase                      |
# | `s.upper()`           | `series.str.upper()`          | Converts string to uppercase                      |
# | `s.title()`           | `series.str.title()`          | Capitalizes first letter of each word             |
# | `s.capitalize()`      | `series.str.capitalize()`     | Capitalizes first letter, rest lowercase          |
# | `s.strip()`           | `series.str.strip()`          | Removes leading/trailing whitespace               |
# | `s.lstrip()`          | `series.str.lstrip()`         | Removes leading whitespace                        |
# | `s.rstrip()`          | `series.str.rstrip()`         | Removes trailing whitespace                       |
# | `s.startswith('a')`   | `series.str.startswith('a')`  | Checks if string starts with given substring      |
# | `s.endswith('z')`     | `series.str.endswith('z')`    | Checks if string ends with given substring        |
# | `'a' in s`            | `series.str.contains('a')`    | Checks if string contains a substring             |
# | `s.replace('a', 'b')` | `series.str.replace('a','b')` | Replaces substring with another                   |
# | `s.find('a')`         | `series.str.find('a')`        | Finds index of first occurrence (-1 if not found) |
# | `s.rfind('a')`        | `series.str.rfind('a')`       | Finds index of last occurrence (-1 if not found)  |
# | `s.isalpha()`         | `series.str.isalpha()`        | Checks if all characters are alphabetic           |
# | `s.isdigit()`         | `series.str.isdigit()`        | Checks if all characters are digits               |
# | `s.isalnum()`         | `series.str.isalnum()`        | Checks if all characters are alphanumeric         |
# | `s.isspace()`         | `series.str.isspace()`        | Checks if string contains only whitespace         |
# | `s.split()`           | `series.str.split()`          | Splits string by whitespace or delimiter          |
# | `' '.join(list)`      | `series.str.join()`           | Joins elements using a string                     |
# | `s.zfill(5)`          | `series.str.zfill(5)`         | Pads string on the left with zeros to fill width  |
# | `s.pad(width)`        | `series.str.pad(width)`       | Pads string with a specified character            |
# | `s.center(width)`     | `series.str.center(width)`    | Centers the string                                |

# %% [markdown]
# #### Methods using regular expressions
#
# In addition, there are several methods that accept regular expressions to examine the content of each string element, and follow some of the API conventions of Python’s built-in re module:
#
# #### Pandas str Methods for Pattern Matching (Regex)
#
# | **Method**   | **Description**                                                         |
# | ------------ | ----------------------------------------------------------------------- |
# | `match()`    | Call `re.match()` on each element, returning a boolean.                 |
# | `extract()`  | Call `re.match()` on each element, returning matched groups as strings. |
# | `findall()`  | Call `re.findall()` on each element.                                    |
# | `replace()`  | Replace occurrences of pattern with some other string.                  |
# | `contains()` | Call `re.search()` on each element, returning a boolean.                |
# | `count()`    | Count occurrences of pattern.                                           |
# | `split()`    | Equivalent to `str.split()`, but accepts regex patterns.                |
# | `rsplit()`   | Equivalent to `str.rsplit()`, but accepts regex patterns.               |

# %% [markdown]
# With these, you can do a wide range of interesting operations.
#
# For example, we can extract the first name from each by asking for a contiguous group of characters at the beginning of each element:

# %%
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: str

# %%
monte.str.extract('([A-Za-z]+)', expand=True)
# Out:
#          0
# 0   Graham
# 1     John
# 2    Terry
# 3     Eric
# 4    Terry
# 5  Michael

# %% [markdown]
# ##### Regex breakdown: '([A-Za-z]+)'
# - [A-Za-z] → Match any uppercase or lowercase letter
# - `+` → Match one or more letters
#
# So it captures the first group of letters found in each string (ignores numbers, symbols, etc.).

# %% [markdown]
# #### Pandas String Manipulation Methods
#
# | **Method**        | **Description**                                                         |
# | ----------------- | ----------------------------------------------------------------------- |
# | `get()`           | Index each element (like accessing characters: e.g., `str[0]`)          |
# | `slice()`         | Slice each element using start/stop/step (like `str[1:4]`)              |
# | `slice_replace()` | Replace a slice in each element with the passed value                   |
# | `cat()`           | Concatenate strings from multiple Series or with a separator            |
# | `repeat()`        | Repeat values (e.g., `'a' * 3` → `'aaa'`)                               |
# | `normalize()`     | Return Unicode-normalized form of string (e.g., NFC, NFD)               |
# | `pad()`           | Add whitespace (or other character) to left, right, or both sides       |
# | `wrap()`          | Wrap long strings into lines of specified width                         |
# | `join()`          | Join strings in each element using a passed separator                   |
# | `get_dummies()`   | Extract dummy/indicator variables from string categories as a DataFrame |

# %% [markdown]
# #### Vectorized item access and slicing
# The `get()` and `slice()` operations, in particular, enable vectorized element access from each array.
#
# For example, we can get a slice of the first three characters of each array using `str.slice(0, 3)`.
#
# Note that this behavior is also available through Python’s normal indexing syntax–for example, `df.str.slice(0, 3)` is equivalent to `df.str[0:3]`:

# %%
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: str

# %%
monte.str[0:3]
# Out:
# 0    Gra
# 1    Joh
# 2    Ter
# 3    Eri
# 4    Ter
# 5    Mic
# dtype: str

# %% [markdown]
# Indexing via `df.str.get(i)` and `df.str[i]` is likewise similar.
#
# These `get()` and `slice()` methods also let you access elements of arrays returned by `split()`.
#
# For example, to extract the last name of each entry, we can combine `split()` and `get()`

# %%
monte.str.split().str.get(-1)
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# 3       Idle
# 4      Jones
# 5      Palin
# dtype: object

# %% [markdown]
# #### Indicator variables
#
# Another method that requires a bit of extra explanation is the `get_dummies()` method.
#
# This is useful when your data has a column containing some sort of coded indicator.
#
# For example, we might have a dataset that contains information in the form of codes, such as A=”born in America,” B=”born in the United Kingdom,” C=”likes cheese,” D=”likes spam”:

# %%
full_monte = pd.DataFrame({'name': monte,
                           'info': ['B|C|D', 'B|D', 'A|C',
                                    'B|D', 'B|C', 'B|C|D']})
full_monte
# Out:
#              name   info
# 0  Graham Chapman  B|C|D
# 1     John Cleese    B|D
# 2   Terry Gilliam    A|C
# 3       Eric Idle    B|D
# 4     Terry Jones    B|C
# 5   Michael Palin  B|C|D

# %% [markdown]
# The `get_dummies()` routine lets you quickly split-out these indicator variables into a DataFrame:

# %%
full_monte['info'].str.get_dummies('|')
# Out:
#    A  B  C  D
# 0  0  1  1  1
# 1  0  1  0  1
# 2  1  0  1  0
# 3  0  1  0  1
# 4  0  1  1  0
# 5  0  1  1  1

# %% [markdown]
# ### Working with Time-Series
#
# Pandas was developed in the context of financial modeling, so as you might expect, it contains a fairly extensive set of tools for working with `dates`, `times`, and `time-indexed` data
#
# Date and time data comes in a the following formats:
#
# - `Time stamps` reference particular moments in time (e.g., July 4th, 2015 at 7:00am).
# - `Time intervals` and `periods` reference a length of time between a particular beginning and end point; for example, the year 2015. Periods usually reference a special case of time intervals in which each interval is of uniform length and does not overlap (e.g., 24 hour-long periods comprising days).
# - `Time deltas` or `durations` reference an exact length of time (e.g., a duration of 22.56 seconds).

# %% [markdown]
# We will start with a brief discussion of tools for dealing with dates and times in Python, before moving more specifically to a discussion of the tools provided by Pandas.

# %% [markdown]
# ### Dates and Times in Python
#
# ##### Native Python dates and times: `datetime` and `dateutil`
#
# Python’s basic objects for working with dates and times reside in the built-in `datetime` module.
#
# Along with the third-party `dateutil` module, you can use it to quickly perform a host of useful functionalities on dates and times.
#
# For example, you can manually build a date using the `datetime` type:

# %%
from datetime import datetime
datetime(year=2015, month=7, day=4)
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %% [markdown]
# using the `dateutil` module, you can parse dates from a variety of string formats

# %%
from dateutil import parser
date = parser.parse("4th of July, 2015")
date
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %% [markdown]
# The `.strftime()` method is used to format a datetime object into a string with a specific date format.

# %%
date.strftime('%Y-%m-%d')
# Out:
# '2015-07-04'

# %% [markdown]
# #### Other Common Format Codes
#
# | Code | Meaning           | Example  |
# | ---- | ----------------- | -------- |
# | `%H` | Hour (00–23)      | `14`     |
# | `%I` | Hour (01–12)      | `02`     |
# | `%p` | AM or PM          | `PM`     |
# | `%M` | Minute (00–59)    | `05`     |
# | `%S` | Second (00–59)    | `09`     |
# | `%A` | Full weekday name | `Monday` |
# | `%B` | Full month name   | `July`   |

# %%
date.strftime('%p')
# Out:
# 'AM'

# %% [markdown]
# #### Typed arrays of times: NumPy’s datetime64
# The weaknesses of Python’s datetime format inspired the NumPy team to add a set of native time series data type to NumPy.
#
# The `datetime64` dtype encodes dates as 64-bit integers, and thus allows arrays of dates to be represented very compactly.

# %%
date = np.array('2015-07-04', dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %% [markdown]
# Once we have this date formatted, however, we can quickly do vectorized operations on it:

# %%
date + np.arange(12)
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %% [markdown]
# Because of the uniform type in `NumPy datetime64` arrays, this type of operation can be accomplished much more quickly than if we were working directly with Python’s datetime objects, especially as arrays get large

# %% [markdown]
# #### Dates and times in pandas: best of both worlds
#
# Pandas builds upon all the tools just discussed to provide a `Timestamp object`, which combines the ease-of-use of `datetime` and `dateutil` with the efficient storage and vectorized interface of `numpy.datetime64`.
#
# From a group of these `Timestamp objects`, Pandas can construct a `DatetimeIndex` that can be used to index data in a `Series` or `DataFrame`; we’ll see many examples of this below.

# %%
date = pd.to_datetime("4th of July, 2015")
date
# Out:
# Timestamp('2015-07-04 00:00:00')

# %% [markdown]
# Additionally, we can do NumPy-style vectorized operations directly on this same object

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#                '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# `pd.to_timedelta(..., 'D')`: Converts each number in np.arange(12) to a time duration in days

# %% [markdown]
# #### Pandas Time Series: Indexing by Time
#
# Where the Pandas time series tools really become useful is when you begin to `index data` by `timestamps`.
#
# For example, we can construct a Series object that has time indexed data:

# %%
index = pd.DatetimeIndex(['2014-07-04', '2014-08-04',
                          '2015-07-04', '2015-08-04'])
data = pd.Series([0, 1, 2, 3], index=index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %% [markdown]
# There are additional special date-only indexing operations, such as passing a year to obtain a slice of all data from that year:

# %%
data['2015']
# Out:
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %% [markdown]
# #### Pandas Time Series Data Structures
# The fundamental Pandas data structures for working with time series data:
#
# - For `time stamps`, Pandas provides the `Timestamp` type. As mentioned before, it is essentially a replacement for Python’s native `datetime`, but is based on the more efficient `numpy.datetime64` data type. The associated Index structure is `DatetimeIndex`.
# - For `time Periods`, Pandas provides the `Period` type. This encodes a fixed-frequency interval based on `numpy.datetime64`. The associated index structure is PeriodIndex.
# - For `time deltas` or `durations`, Pandas provides the `Timedelta` type. Timedelta is a more efficient replacement for Python’s native `datetime.timedelta` type, and is based on `numpy.timedelta64`. The associated index structure is `TimedeltaIndex`.

# %% [markdown]
# The most fundamental of these date/time objects are the `Timestamp` and `DatetimeIndex` objects.
#
# While these class objects can be invoked directly, it is more common to use the `pd.to_datetime()` function, which can parse a wide variety of formats.
#
# Passing a single date to `pd.to_datetime()` yields a `Timestamp`; passing a series of dates by default yields a `DatetimeIndex`:

# %% [markdown]
# ### Time Series with Superstore Data

# %% [markdown]
# #### Load and Explore the Dataset

# %%
import pandas as pd

df = pd.read_csv("superstore (1).csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     2.0  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     3.0  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     4.0  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     5.0  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   float64
#  1   Order ID       9800 non-null   str
#  2   Order Date     9800 non-null   str
#  3   Ship Date      9800 non-null   str
#  4   Ship Mode      9800 non-null   str
#  5   Customer ID    9800 non-null   str
#  6   Customer Name  9800 non-null   str
#  7   Segment        9800 non-null   str
#  8   Country        9800 non-null   str
#  9   City           9800 non-null   str
#  10  State          9800 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   str
#  13  Product ID     9800 non-null   str
#  14  Category       9800 non-null   str
#  15  Sub-Category   9800 non-null   str
#  16  Product Name   9800 non-null   str
#  17  Sales          9800 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(5), int64(1), str(15)
# memory usage: 3.3 MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9800.000000   9789.000000   9800.000000  9994.000000  9994.000000
# mean   4900.500000  55273.322403    230.769059     3.789574     0.156203
# std    2829.160653  32041.223413    626.651875     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2450.750000  23223.000000     17.248000     2.000000     0.000000
# 50%    4900.500000  58103.000000     54.490000     3.000000     0.200000
# 75%    7350.250000  90008.000000    210.605000     5.000000     0.200000
# max    9800.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Row ID           194
# Order ID         194
# Order Date       194
# Ship Date        194
# Ship Mode        194
# Customer ID      194
# Customer Name    194
# Segment          194
# Country          194
# City             194
# State            194
# Postal Code      205
# Region           194
# Product ID       194
# Category         194
# Sub-Category     194
# Product Name     194
# Sales            194
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ## Questions we can answer with the data

# %% [markdown]
# ### How much total sales were generated?

# %%
df['Sales'].sum()
# Out:
# np.float64(2261536.7827)

# %% [markdown]
# ### Which category generates the most sales?

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %% [markdown]
# ### Sales and Profit by Category

# %%
df.pivot_table(
    values=['Sales', 'Profit'],
    index='Category',
    aggfunc='sum'
)
# Out:
#                       Profit        Sales
# Category
# Furniture         16921.6842  728658.5757
# Office Supplies  118956.3861  705422.3340
# Technology       143100.5405  827455.8730

# %% [markdown]
# ### Sales and Profit by Region

# %%
pivot = df.pivot_table(
    values=['Sales', 'Profit'],
    index='Region',
    aggfunc='sum'
)

pivot.sort_values('Sales', ascending=False)
# Out:
#               Profit        Sales
# Region
# West     105357.2069  710219.6845
# East      89512.0804  669518.7260
# Central   37866.0619  492646.9132
# South     46243.2616  389151.4590

# %% [markdown]
# ### What does each customer segment spend on?

# %%
df.pivot_table(
    values='Sales',
    index='Segment',
    columns='Category',
    aggfunc='sum'
)
# Out:
# Category       Furniture  Office Supplies  Technology
# Segment
# Consumer     387696.2580       359352.608  401011.665
# Corporate    220321.7018       224130.536  244041.837
# Home Office  120640.6159       121939.190  182402.371

# %% [markdown]
# ### Which sub-category generates the most sales?

# %%
df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Furnishings     89212.0180
# Paper           76828.3040
# Supplies        46420.3080
# Art             26705.4100
# Envelopes       16128.0460
# Labels          12347.7260
# Fasteners        3001.9600
# Name: Sales, dtype: float64

# %% [markdown]
# ## Profit analysis

# %% [markdown]
# ### Which categories are the most profitable?

# %%
df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         143100.5405
# Office Supplies    118956.3861
# Furniture           16921.6842
# Name: Profit, dtype: float64

# %% [markdown]
# ## Regional analysis

# %% [markdown]
# ### Which region generates the most sales?

# %%
df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
# Out:
# Region
# West       105357.2069
# East        89512.0804
# South       46243.2616
# Central     37866.0619
# Name: Profit, dtype: float64

# %% [markdown]
# ## Customer analysis

# %% [markdown]
# ### Who are the top 10 customers by sales?

# %%
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Set Order Date as a DatetimeIndex

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
#     256     try:
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\tools\datetimes.py:470, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     459 def _array_strptime_with_fallback(
#     460     arg,
#     461     name,
#    (...)    465     errors: str,
#     466 ) -> Index:
#     467     """
#     468     Call array_strptime, with fallback behavior depending on 'errors'.
#     469     """
# --> 470     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     471     if tz_out is not None:
#     472         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:563, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:511, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:617, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "15/04/2018" doesn't match format "%m/%d/%Y". You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Set Order Date as Index (for Resampling)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1     2.0  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2     3.0  CA-2017-138688 2017-06-12  16/06/2017    Second Class    DV-13045
# 3     4.0  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
# 4     5.0  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df = df.set_index('Order Date')

# %%
df.head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-11-08     1.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-11-08     2.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-06-12     3.0  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 2016-10-11     4.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 2016-10-11     5.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                  State  Postal Code Region       Product ID         Category  \
# Order Date
# 2017-11-08    Kentucky      42420.0  South  FUR-BO-10001798        Furniture
# 2017-11-08    Kentucky      42420.0  South  FUR-CH-10000454        Furniture
# 2017-06-12  California      90036.0   West  OFF-LA-10000240  Office Supplies
# 2016-10-11     Florida      33311.0  South  FUR-TA-10000577        Furniture
# 2016-10-11     Florida      33311.0  South  OFF-ST-10000760  Office Supplies
#
#            Sub-Category                                       Product Name  \
# Order Date
# 2017-11-08    Bookcases                  Bush Somerset Collection Bookcase
# 2017-11-08       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2017-06-12       Labels  Self-Adhesive Address Labels for Typewriters b...
# 2016-10-11       Tables      Bretford CR4500 Series Slim Rectangular Table
# 2016-10-11      Storage                     Eldon Fold 'N Roll Cart System
#
#                Sales  Quantity  Discount    Profit
# Order Date
# 2017-11-08  261.9600         2      0.00   41.9136
# 2017-11-08  731.9400         3      0.00  219.5820
# 2017-06-12   14.6200         2      0.00    6.8714
# 2016-10-11  957.5775         5      0.45 -383.0310
# 2016-10-11   22.3680         2      0.20    2.5164

# %%
df.set_index('Order Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7740\1446172014.py in ?()
# ----> 1 df.set_index('Order Date', inplace=True)
#       2 df.head()
#
# c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6973                     if not found:
#    6974                         missing.append(col)
#    6975
#    6976         if missing:
# -> 6977             raise KeyError(f"None of {missing} are in the columns")
#    6978
#    6979         if inplace:
#    6980             frame = self
#
# KeyError: "None of ['Order Date'] are in the columns"

# %% [markdown]
# #### Work with Timestamps
# A `Timestamp` represents a specific point in time.

# %%
df.head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-11-08     1.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-11-08     2.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-06-12     3.0  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 2016-10-11     4.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 2016-10-11     5.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                  State  Postal Code Region       Product ID         Category  \
# Order Date
# 2017-11-08    Kentucky      42420.0  South  FUR-BO-10001798        Furniture
# 2017-11-08    Kentucky      42420.0  South  FUR-CH-10000454        Furniture
# 2017-06-12  California      90036.0   West  OFF-LA-10000240  Office Supplies
# 2016-10-11     Florida      33311.0  South  FUR-TA-10000577        Furniture
# 2016-10-11     Florida      33311.0  South  OFF-ST-10000760  Office Supplies
#
#            Sub-Category                                       Product Name  \
# Order Date
# 2017-11-08    Bookcases                  Bush Somerset Collection Bookcase
# 2017-11-08       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2017-06-12       Labels  Self-Adhesive Address Labels for Typewriters b...
# 2016-10-11       Tables      Bretford CR4500 Series Slim Rectangular Table
# 2016-10-11      Storage                     Eldon Fold 'N Roll Cart System
#
#                Sales  Quantity  Discount    Profit
# Order Date
# 2017-11-08  261.9600         2      0.00   41.9136
# 2017-11-08  731.9400         3      0.00  219.5820
# 2017-06-12   14.6200         2      0.00    6.8714
# 2016-10-11  957.5775         5      0.45 -383.0310
# 2016-10-11   22.3680         2      0.20    2.5164

# %%
df.loc['11/10/2016']
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-10   266.0  CA-2016-155040  15/11/2016  Standard Class    AH-10210
# 2016-11-10  5006.0  CA-2016-158659  14/11/2016    Second Class    SC-20695
# 2016-11-10  5849.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5850.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5851.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5852.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5853.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  9552.0  CA-2016-147690  14/11/2016  Standard Class    SC-20020
#
#                 Customer Name      Segment        Country          City  \
# Order Date
# 2016-11-10         Alan Hwang     Consumer  United States     Brentwood
# 2016-11-10      Steve Chapman    Corporate  United States      Richmond
# 2016-11-10  Philisse Overcash  Home Office  United States     Roseville
# 2016-11-10  Philisse Overcash  Home Office  United States     Roseville
# 2016-11-10  Philisse Overcash  Home Office  United States     Roseville
# 2016-11-10  Philisse Overcash  Home Office  United States     Roseville
# 2016-11-10  Philisse Overcash  Home Office  United States     Roseville
# 2016-11-10         Sam Craven     Consumer  United States  Philadelphia
#
#                    State  Postal Code   Region       Product ID  \
# Order Date
# 2016-11-10    California      94513.0     West  TEC-AC-10004469
# 2016-11-10       Indiana      47374.0  Central  OFF-ST-10003306
# 2016-11-10     Minnesota      55113.0  Central  OFF-AP-10003849
# 2016-11-10     Minnesota      55113.0  Central  OFF-ST-10000078
# 2016-11-10     Minnesota      55113.0  Central  TEC-CO-10001571
# 2016-11-10     Minnesota      55113.0  Central  OFF-BI-10001658
# 2016-11-10     Minnesota      55113.0  Central  FUR-FU-10004351
# 2016-11-10  Pennsylvania      19140.0     East  OFF-ST-10001526
#
#                    Category Sub-Category  \
# Order Date
# 2016-11-10       Technology  Accessories
# 2016-11-10  Office Supplies      Storage
# 2016-11-10  Office Supplies   Appliances
# 2016-11-10  Office Supplies      Storage
# 2016-11-10       Technology      Copiers
# 2016-11-10  Office Supplies      Binders
# 2016-11-10        Furniture  Furnishings
# 2016-11-10  Office Supplies      Storage
#
#                                               Product Name    Sales  Quantity  \
# Order Date
# 2016-11-10                  Microsoft Sculpt Comfort Mouse   79.900         2
# 2016-11-10                                Letter Size Cart  714.300         5
# 2016-11-10  Hoover Shoulder Vac Commercial Portable Vacuum  715.640         2
# 2016-11-10           Tennsco 6- and 18-Compartment Lockers  795.510         3
# 2016-11-10               Sharp 1540cs Digital Laser Copier  549.990         1
# 2016-11-10                GBC Standard Therm-A-Bind Covers   74.760         3
# 2016-11-10                      Staple-based wall hangings   29.220         3
# 2016-11-10           Iceberg Mobile Mega Data/Printer Cart  577.584         6
#
#             Discount    Profit
# Order Date
# 2016-11-10       0.0   35.1560
# 2016-11-10       0.0  207.1470
# 2016-11-10       0.0  178.9100
# 2016-11-10       0.0  143.1918
# 2016-11-10       0.0  274.9950
# 2016-11-10       0.0   34.3896
# 2016-11-10       0.0   12.8568
# 2016-11-10       0.2   43.3188

# %% [markdown]
# #### Resample Sales by Month and Plot

# %%
monthly_sales = df['Sales'].resample('ME').sum()
monthly_sales.plot(title="Monthly Sales Trend", figsize=(10,4))
# Out:
# <Axes: title={'center': 'Monthly Sales Trend'}, xlabel='Order Date'>

# %% [markdown]
# - `resample('M')`: Groups data by month
# - You can also try `Q` for quarterly, `Y` for yearly

# %% [markdown]
# #### Work with Periods
# A `Period` is a span of time (e.g., month or quarter)

# %%
df['Order_Period'] = df.index.to_period('D')
monthly_sales = df.groupby('Order_Period')['Sales'].sum()
monthly_sales.plot(title="Monthly Sales")
# Out:
# <Axes: title={'center': 'Monthly Sales'}, xlabel='Order_Period'>

# %% [markdown]
# #### Work with Timedeltas (Delivery Time)
# A `Timedelta` is the time difference between two dates.

# %%
df['Delivery_Days'] = (df['Ship Date'] - df.index).dt.days
print(df[['Ship Date', 'Delivery_Days']].head())
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arrays\arrow\array.py:1029, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1028 try:
# -> 1029     result = pc_func(self._pa_array, other)
#    1030 except pa.ArrowNotImplementedError as err:
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pyarrow\compute.py:254, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     253     return Expression._call(func_name, list(args))
# --> 254 return func.call(args, None, memory_pool)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pyarrow\_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Function 'subtract_checked' has no kernel matching input types (large_string, timestamp[us])
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df['Delivery_Days'] = (df['Ship Date'] - df.index).dt.days
#       2 print(df[['Ship Date', 'Delivery_Days']].head())
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\series.py:6751, in Series._arith_method(self, other, op)
#    6749 def _arith_method(self, other, op):
#    6750     self, other = self._align_for_op(other)
# -> 6751     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\base.py:1644, in IndexOpsMixin._arith_method(self, other, op)
#    1641     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1643 with np.errstate(all="ignore"):
# -> 1644     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1646 return self._construct_result(result, name=res_name, other=other)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\ops\array_ops.py:279, in arithmetic_op(left, right, op)
#     270 right = ensure_wrapped_if_datetimelike(right)
#     272 if (
#     273     should_extension_dispatch(left, right)
#     274     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    277     # Timedelta/Timestamp and other custom scalars are included in the check
#     278     # because numexpr will fail on it, see GH#31457
# --> 279     res_values = op(left, right)
#     280 else:
#     281     # TODO we should handle EAs consistently and move this check before the if/else
#     282     # (https://github.com/pandas-dev/pandas/issues/41165)
#     283     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arrays\arrow\array.py:1079, in ArrowExtensionArray._arith_method(self, other, op)
#    1062 if (
#    1063     op in [operator.truediv, roperator.rtruediv]
#    1064     and isinstance(other, Path)
#    (...)   1069 ):
#    1070     # GH#61940
#    1071     return np.array(
#    1072         [
#    1073             op(x, other) if isinstance(x, str) else self.dtype.na_value
#    (...)   1076         dtype=object,
#    1077     )
# -> 1079 result = self._evaluate_op_method(other, op, ARROW_ARITHMETIC_FUNCS)
#    1080 if is_nan_na() and result.dtype.kind == "f":
#    1081     parr = result._pa_array
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arrays\arrow\array.py:1031, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1029     result = pc_func(self._pa_array, other)
#    1030 except pa.ArrowNotImplementedError as err:
# -> 1031     raise TypeError(self._op_method_error_message(other_original, op)) from err
#    1032 return self._from_pyarrow_array(result)
#
# TypeError: operation 'sub' not supported for dtype 'str' with dtype 'datetime64[us]'

# %%
# Create a column from index 
df['Order_Date'] = df.index

# %%
# Ensure both columns are datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
# Compute delivery time
df['Delivery_Days'] = (df['Ship Date'] - df['Order_Date']).dt.days

# %%
print(df[['Order_Date', 'Ship Date', 'Delivery_Days']].head())
# Out:
#            Order_Date  Ship Date  Delivery_Days
# Order Date
# 2017-11-08 2017-11-08 2017-11-11            3.0
# 2017-11-08 2017-11-08 2017-11-11            3.0
# 2017-06-12 2017-06-12 2017-06-16            4.0
# 2016-10-11 2016-10-11 2016-10-18            7.0
# 2016-10-11 2016-10-11 2016-10-18            7.0

# %% [markdown]
# #### Google Stock Price Data with yfinance

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Download Daily Stock Data

# %%
# Download Google stock data from Jan 1, 2020 to present
goog = yf.download('GOOGL', start='2020-01-01')
goog.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker          GOOGL      GOOGL      GOOGL      GOOGL     GOOGL
# Date
# 2020-01-02  67.832520  67.832520  66.732774  66.827931  27278000
# 2020-01-03  67.477654  68.083782  66.773895  66.807600  23408000
# 2020-01-06  69.276222  69.301496  66.956293  66.987511  46768000
# 2020-01-07  69.142395  69.558210  68.966457  69.407546  34330000
# 2020-01-08  69.634537  69.972044  69.019492  69.128026  35314000

# %%
goog.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2026-03-25  290.929993  296.000000  289.239990  293.440002  29460700
# 2026-03-26  280.920013  287.950012  278.500000  287.910004  39080600
# 2026-03-27  274.339996  279.369995  273.950012  277.279999  35890600
# 2026-03-30  273.500000  277.089996  272.109985  276.420013  35141200
# 2026-03-31  287.559998  288.070007  277.089996  278.040009  42262462

# %% [markdown]
# ##### Date Indexing and Filtering

# %%
goog.loc['2022']               # Data for 2022
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2022-01-03  143.802963  144.655415  142.534940  143.865935  28646000
# 2022-01-04  143.215820  145.284220  142.538420  144.204142  28400000
# 2022-01-05  136.645630  143.315011  136.559353  143.236164  54618000
# 2022-01-06  136.618347  138.792880  135.439098  135.875494  37348000
# 2022-01-07  135.893814  137.313583  134.653561  137.013058  29760000
# ...                ...         ...         ...         ...       ...
# 2022-12-23   88.498566   88.815942   86.356268   86.395941  23003000
# 2022-12-27   86.673637   88.210935   86.296755   88.072083  20097300
# 2022-12-28   85.314865   87.318311   85.235527   86.267002  19523200
# 2022-12-29   87.724953   88.121675   85.900039   85.909959  23333500
# 2022-12-30   87.506752   87.576178   85.860356   86.266999  23986300
#
# [251 rows x 5 columns]

# %%
goog.loc['2023-03']            # Data for March 2023
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2023-03-01   89.619308   90.283815   88.934962   89.242426  31111200
# 2023-03-02   91.245850   91.523553   88.855601   88.925035  32204400
# 2023-03-03   92.882317   92.961663   91.692149   91.721909  35160100
# 2023-03-06   94.350204   95.183323   93.229470   93.249303  32639300
# 2023-03-07   93.090607   94.885767   92.763310   94.201428  27835500
# 2023-03-08   93.477409   95.173391   93.229459   93.348478  34103300
# 2023-03-09   91.563225   94.746911   91.146669   93.279047  28813500
# 2023-03-10   89.887077   92.029375   89.658967   91.414454  35941000
# 2023-03-13   90.363152   91.811183   88.687002   89.351508  37335600
# 2023-03-14   93.199715   93.586517   91.682258   91.801269  36050200
# 2023-03-15   95.322159   96.135437   91.880602   92.455850  50622100
# 2023-03-16   99.497658  100.360529   94.717169   95.411427  65492000
# 2023-03-17  100.787003  101.996996   99.279458   99.438150  61028500
# 2023-03-20  100.390282  100.915936   99.051349   99.299300  32960400
# 2023-03-21  104.059944  104.238469  100.390277  100.420030  42110300
# 2023-03-22  102.522659  105.716258  102.482986  103.415276  43427400
# 2023-03-23  104.734375  105.428642  103.603720  104.198801  40797800
# 2023-03-24  104.575691  104.625277  102.988801  104.129375  30393300
# 2023-03-27  101.620117  103.901267  101.094463  103.762415  31120900
# 2023-03-28  100.201836  101.610194   98.922409  101.600281  32057900
# 2023-03-29  100.558884  101.649865   99.824952  101.441588  28779600
# 2023-03-30  100.062981  100.330772   98.962079  100.082821  33086200
# 2023-03-31  102.879707  103.038392  100.211755  100.469626  36863400

# %%
goog.loc['2022-05-10']     # Specific day
# Out:
# Price   Ticker
# Close   GOOGL     1.134573e+02
# High    GOOGL     1.152971e+02
# Low     GOOGL     1.119750e+02
# Open    GOOGL     1.145607e+02
# Volume  GOOGL     3.990000e+07
# Name: 2022-05-10 00:00:00, dtype: float64

# %% [markdown]
# ##### Resampling

# %%
# Monthly average close price
goog['Close'].resample('ME').mean()
# Out:
# Ticker           GOOGL
# Date
# 2020-01-31   71.176836
# 2020-02-29   72.499811
# 2020-03-31   58.736332
# 2020-04-30   60.964983
# 2020-05-31   68.461560
# ...                ...
# 2026-03-31  298.528322
# 2026-04-30  330.653929
# 2026-05-31  390.915508
# 2026-06-30  359.327279
# 2026-07-31  349.190908
#
# [79 rows x 1 columns]

# %%
# Weekly closing price sum
goog['Close'].resample('W').sum()
# Out:
# Ticker            GOOGL
# Date
# 2020-01-05   135.310173
# 2020-01-12   349.238747
# 2020-01-19   358.793488
# 2020-01-26   293.248680
# 2020-02-02   358.122475
# ...                 ...
# 2026-07-05  1432.139984
# 2026-07-12  1811.480011
# 2026-07-19  1784.170013
# 2026-07-26  1678.659973
# 2026-08-02  1686.769989
#
# [344 rows x 1 columns]
