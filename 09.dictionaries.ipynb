# %% [markdown]
# ## Dictionary
#
# A **dictionary** in Python is an **unordered**, **mutable**, and **indexed** collection of key-value pairs.
# Each item in a dictionary is stored as:
#
# ```key: value```
#
# - **Keys** must be unique and immutable (e.g., strings, numbers, tuples).
# - **Values** can be of any data type and can repeat.

# %% [markdown]
# ### Creating a Dictionary

# %%
# empty dictionary
empty = {}
empty
# Out:
# {}

# %%
student = {
        "name" : "Mercy Mwangi",
        "age" : 25,
        "grade" : "A"
}
student
# Out:
# {'name': 'Mercy Mwangi', 'age': 25, 'grade': 'A'}

# %%
students = {
        "name" : ["Mercy", "Bob", "Bethwel", "Amos", "Nicloe"],
        "age" : [25, 27, 21, 23, 28],
        "grade" : ["A", "B", "A", "C", "D"]
}

students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Amos', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28],
#  'grade': ['A', 'B', 'A', 'C', 'D']}

# %%
#dictionary with data
student = {
    "name": "John Doe",
    "age": 21,
    "grade": "A"
}
student
# Out:
# {'name': 'John Doe', 'age': 21, 'grade': 'A'}

# %%
students = {
    "names": ["Alice", "Bob", "Charlie"],
    "age": [20, 22, 23],
    "grades": ["A", "D", "B"]
}
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 23],
#  'grades': ['A', 'D', 'B']}

# %% [markdown]
# ### Common Dictionary Methods
#
# | Method       | Description                         | Example                              |
# |--------------|-------------------------------------|--------------------------------------|
# | `get(key)`   | Get value for key                   | `student.get('age')`                 |
# | `keys()`     | Returns all keys                    | `student.keys()`                     |
# | `values()`   | Returns all values                  | `student.values()`                   |
# | `items()`    | Returns (key, value) pairs          | `student.items()`                    |
# | `update()`   | Updates dictionary with another     | `student.update({'age': 23})`        |
# | `pop(key)`   | Removes key and returns value       | `student.pop('grade')`               |
# | `clear()`    | Clears all items                    | `student.clear()`                    |

# %%
#Acces the dictionary values
student
# Out:
# {'name': 'Mercy Mwangi', 'age': 25, 'grade': 'A'}

# %%
student.get("grade")
# Out:
# 'A'

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.pop('grade')
student
# Out:
# {'name': 'Mercy Mwangi', 'age': 23}

# %%
student.values()
# Out:
# dict_values(['Mercy Mwangi', 25, 'A'])

# %%
student
# Out:
# {'name': 'Mercy Mwangi', 'age': 25, 'grade': 'A'}

# %%
student.update({'age': 23})
student
# Out:
# {'name': 'Mercy Mwangi', 'age': 23, 'grade': 'A'}

# %%
student.items()
# Out:
# dict_items([('name', 'Mercy Mwangi'), ('age', 25), ('grade', 'A')])

# %% [markdown]
# #### Accessing Dictionary Values

# %%
student
# Out:
# {'name': 'John Doe', 'age': 21, 'grade': 'A'}

# %%
print(student.get("grade"))
# Out:
# A

# %%
student['age']
# Out:
# 21

# %%
#Access the name using the index
student["name"]
# Out:
# 'John Doe'

# %%
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Amos', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28],
#  'grade': ['A', 'B', 'A', 'C', 'D']}

# %%
students["name"]
# Out:
# ['Mercy', 'Bob', 'Bethwel', 'Amos', 'Nicloe']

# %%
students["name"][3] = "Sheila"
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28],
#  'grade': ['A', 'B', 'A', 'C', 'D']}

# %%
students["grade"][2] = "E"
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28],
#  'grade': ['A', 'B', 'E', 'C', 'D']}

# %%
students.pop("grade")
# Out:
# ['A', 'B', 'E', 'C', 'D']

# %%
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28]}

# %%
#students.get("names")
students["age"][1]
# Out:
# 22

# %% [markdown]
# ### Updating and Adding Items

# %%
# update 
students["age"][2] = 27
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'grades': ['A', 'D', 'B']}

# %%
students["email"] = ["alice@example.com"]
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'grades': ['A', 'D', 'B'],
#  'email': ['alice@example.com']}

# %% [markdown]
# ### Removing Items

# %%
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28]}

# %%
students.update({'grade': ["A", "B", "C", "A"]})
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28],
#  'grade': ['A', 'B', 'C', 'A']}

# %%
students.pop("")
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'email': ['alice@example.com']}

# %% [markdown]
# ### Applying Dictionaries:
# - Loop through keys/values:

# %%
students
# Out:
# {'name': ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'],
#  'age': [25, 27, 21, 23, 28]}

# %%
for key in students.items():
    print(key)
# Out:
# ('name', ['Mercy', 'Bob', 'Bethwel', 'Sheila', 'Nicloe'])
# ('age', [25, 27, 21, 23, 28])

# %%
"name" in students
# Out:
# True

# %%
for key in students.items():
    print(key)
# Out:
# ('names', ['Alice', 'Bob', 'Charlie'])
# ('age', [20, 22, 27])
# ('email', ['alice@example.com'])

# %% [markdown]
# - Check if a key exists:

# %%
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'email': ['alice@example.com']}

# %%
"Faculty" in students
# Out:
# False

# %% [markdown]
# ### Nested Dictionaries
#
# - You can create dictionaries inside dictionaries:

# %%
students = {
    "student1": {
        "name": "Ricarda",
        "age": 25,
        "grade": "B"
    },

    "student2": {
        "name": "Michael",
        "age": 28,
        "grade": "A"
    }
}
students
# Out:
# {'student1': {'name': 'Ricarda', 'age': 25, 'grade': 'B'},
#  'student2': {'name': 'Michael', 'age': 28, 'grade': 'A'}}

# %%
students["student2"]["name"]
# Out:
# 'Michael'

# %%
# Dictionary with tuples as the values
my_dict = {
    'apple' : (2, 4),
    'banana' : (1, 3),
    'orange': (5,),
    'mango' : (6, 2, 1)
}


total = sum([num for values in my_dict.values() for num in values])
print(total)
# Out:
# 24
